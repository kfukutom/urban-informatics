# %%
import requests 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('URA_data.csv', index_col=0)
df = pd.get_dummies(df, columns = ['Type'], drop_first = True)
print(df.shape, '\n')
print(df.columns, '\n')
print(df.dtypes, '\n')

for col in df:
    print(df[col].value_counts())
# Out:
# (92622, 15)
#
# Index(['Project Name', 'Street Name', 'Postal District', 'Market Segment',
#        'Tenure', 'Type of Sale', 'No. of Units', 'Price ($)', 'Nett Price ($)',
#        'Area (Sqft)', 'Type of Area', 'Floor Level', 'Unit Price ($psf)',
#        'Date of Sale', 'Type_Condominium'],
#       dtype='object')
#
# Project Name         object
# Street Name          object
# Postal District       int64
# Market Segment       object
# Tenure               object
# Type of Sale         object
# No. of Units          int64
# Price ($)             int64
# Nett Price ($)       object
# Area (Sqft)           int64
# Type of Area         object
# Floor Level          object
# Unit Price ($psf)     int64
# Date of Sale         object
# Type_Condominium       bool
# dtype: object
#
# Project Name
# TREASURE AT TAMPINES     1715
# PARC ESTA                1383
# RIVERFRONT RESIDENCES    1370
# STIRLING RESIDENCES      1202
# JADESCAPE                1125
#                          ...
# VILLA D'ESTE                1
# THE SILVERTON               1
# DONG XING COURT             1
# ST PATRICK'S GREEN          1
# MARINE VILLE                1
# Name: count, Length: 2258, dtype: int64
# Street Name
# TAMPINES STREET 86    2036
# WEST COAST VALE       1961
# TAMPINES LANE         1715
# JALAN LEMPENG         1699
# HOUGANG AVENUE 7      1447
#                       ...
# JOO AVENUE               1
# JALAN WANGI              1
# HAIG LANE                1
# JALAN SUKA               1
# KALIDASA AVENUE          1
# Name: count, Length: 828, dtype: int64
# Postal District
# 19    11054
# 5      7897
# 3      6752
# 15     6595
# 18     6473
# 14     6079
# 10     5369
# 9      5279
# 23     4031
# 21     3789
# 16     3564
# 13     3262
# 20     3050
# 12     2760
# 11     2321
# 27     2200
# 28     1889
# 22     1855
# 17     1556
# 4      1531
# 8      1268
# 1      1078
# 2      1002
# 7       900
# 26      578
# 25      485
# 6         5
# Name: count, dtype: int64
# Market Segment
# OCR    44479
# RCR    32809
# CCR    15334
# Name: count, dtype: int64
# Tenure
# Freehold                                 25287
# 99 yrs lease commencing from 2018        11694
# 99 yrs lease commencing from 2015         5353
# 99 yrs lease commencing from 2017         5012
# 99 yrs lease commencing from 2016         4799
#                                          ...
# 9999 yrs lease commencing from 1964          1
# 9999 yrs lease commencing from 1965          1
# 999999 yrs lease commencing from 1963        1
# 999 yrs lease commencing from 1958           1
# 999 yrs lease commencing from 1979           1
# Name: count, Length: 127, dtype: int64
# Type of Sale
# Resale      45997
# New Sale    45071
# Sub Sale     1554
# Name: count, dtype: int64
# No. of Units
# 1      92516
# 2         19
# 12         5
# 4          4
# 20         4
#        ...
# 61         1
# 33         1
# 79         1
# 104        1
# 14         1
# Name: count, Length: 62, dtype: int64
# Price ($)
# 1200000      671
# 1100000      590
# 1300000      565
# 1050000      537
# 1500000      519
#             ...
# 223938000      1
# 1667640        1
# 6215600        1
# 1693840        1
# 759112         1
# Name: count, Length: 16950, dtype: int64
# Nett Price ($)
# -          91992
# 800000         3
# 1045000        3
# 1261000        3
# 821000         3
#            ...
# 766000         1
# 775000         1
# 1316000        1
# 1283000        1
# 1533920        1
# Name: count, Length: 568, dtype: int64
# Area (Sqft)
# 463       1603
# 678       1403
# 700       1398
# 764       1398
# 484       1396
#           ...
# 70461        1
# 416750       1
# 47660        1
# 19741        1
# 1680         1
# Name: count, Length: 627, dtype: int64
# Type of Area
# Strata    92601
# Land         21
# Name: count, dtype: int64
# Floor Level
# 01 to 05    33272
# 06 to 10    23555
# 11 to 15    16619
# 16 to 20     8602
# 21 to 25     4247
# 26 to 30     2700
# 31 to 35     1932
# 36 to 40      933
# 41 to 45      318
# -             162
# 46 to 50      123
# 51 to 55       61
# 56 to 60       35
# 61 to 65       25
# 66 to 70       21
# B1 to B5       13
# 71 to 75        4
# Name: count, dtype: int64
# Unit Price ($psf)
# 929     269
# 1394    249
# 1548    212
# 1161    180
# 1327    165
#        ...
# 3266      1
# 3637      1
# 3694      1
# 3648      1
# 471       1
# Name: count, Length: 3187, dtype: int64
# Date of Sale
# Jul-18    2562
# Mar-17    2560
# May-18    2434
# Jan-21    2432
# Apr-17    2323
#           ...
# Jan-17     756
# May-20     596
# Apr-20     544
# Feb-16     488
# Feb-21      50
# Name: count, Length: 61, dtype: int64
# Type_Condominium
# True     52825
# False    39797
# Name: count, dtype: int64

# %%
df['Lease_length'] = df['Tenure'].str.extract(r'([0-9]+) [Yy]rs')
df['Lease_start'] = df['Tenure'].str.extract(r'([0-9]+)[\s]*$')
df['Building_age'] = ((pd.to_datetime(df['Date of Sale'], format = '%b-%y')) - (pd.to_datetime(df['Lease_start'])))

# %%
df['Lease_length'] = df['Lease_length'].astype(float)
df['Date of Sale'] = pd.to_datetime(df['Date of Sale'], format='%b-%y', errors='coerce')
df['Lease_start'] = pd.to_datetime(df['Lease_start'], errors='coerce')

# Calculate 'Remaining_tenure'
df['Remaining_tenure'] = df['Lease_length'].astype(float) - (
    (df['Date of Sale'] - df['Lease_start']) / np.timedelta64(1, 'D') / 365.25)

"""
    Read Me: Interpreting the relativity tenure, gives us a score of
    what the building's categorized tenure to be. For example, freehold and
    leasehold buildings will be placed at the exact uniform value of 1.0 (valtype=float)
"""
# Calculate the Relativity of the Tenure
df['Relative_tenure'] = 1.0 - 1.0 / ( ( 1.0 + df['Remaining_tenure'] / 208.96) ** 6.8828)
df.loc[df['Tenure'] == 'Freehold', 'Relative_tenure'] = 1.0

df
# Out:
#                  Project Name          Street Name  Postal District  \
# S/N
# 1                 ONE SHENTON          SHENTON WAY                1
# 2       LANDRIDGE CONDOMINIUM   PASIR PANJANG ROAD                5
# 3               THE ANCHORAGE       ALEXANDRA ROAD                3
# 4        THE PARC CONDOMINIUM      WEST COAST WALK                5
# 5         COMMONWEALTH TOWERS  COMMONWEALTH AVENUE                3
# ...                       ...                  ...              ...
# 4663          SYMPHONY SUITES         YISHUN CLOSE               27
# 4664          SYMPHONY SUITES         YISHUN CLOSE               27
# 4665               FLORAVILLE          CACTUS ROAD               28
# 4666  ORCHID PARK CONDOMINIUM     YISHUN STREET 81               27
# 4667     HIGH PARK RESIDENCES        FERNVALE ROAD               28
#
#      Market Segment                             Tenure Type of Sale  \
# S/N
# 1               CCR  99 yrs lease commencing from 2005       Resale
# 2               RCR                           Freehold       Resale
# 3               RCR                           Freehold       Resale
# 4               OCR                           Freehold       Resale
# 5               RCR  99 yrs lease commencing from 2013       Resale
# ...             ...                                ...          ...
# 4663            OCR  99 yrs lease commencing from 2014     New Sale
# 4664            OCR  99 yrs lease commencing from 2014     New Sale
# 4665            OCR                           Freehold     New Sale
# 4666            OCR  99 yrs lease commencing from 1991       Resale
# 4667            OCR  99 yrs lease commencing from 2014     New Sale
#
#       No. of Units  Price ($) Nett Price ($)  Area (Sqft) Type of Area  \
# S/N
# 1                1    2250000              -         1582       Strata
# 2                1    2360000              -         1830       Strata
# 3                1    1860000              -         1378       Strata
# 4                1    1800000              -         1927       Strata
# 5                1    1225000              -          689       Strata
# ...            ...        ...            ...          ...          ...
# 4663             1     786000              -          797       Strata
# 4664             1     973000              -          915       Strata
# 4665             1     763000              -          570       Strata
# 4666             1     710000              -          980       Strata
# 4667             1     936112              -          980       Strata
#
#      Floor Level  Unit Price ($psf) Date of Sale  Type_Condominium  \
# S/N
# 1       21 to 25               1422   2021-02-01             False
# 2       01 to 05               1290   2021-02-01              True
# 3       01 to 05               1350   2021-02-01              True
# 4       01 to 05                934   2021-02-01              True
# 5       06 to 10               1778   2021-02-01              True
# ...          ...                ...          ...               ...
# 4663    01 to 05                987   2016-02-01              True
# 4664    11 to 15               1063   2016-02-01              True
# 4665    01 to 05               1337   2016-02-01             False
# 4666    01 to 05                725   2016-02-01              True
# 4667    06 to 10                956   2016-02-01             False
#
#       Lease_length Lease_start Building_age  Relative_tenure  Remaining_tenure
# S/N
# 1             99.0  2005-01-01    5875 days         0.899753         82.915127
# 2              NaN         NaT          NaT         1.000000               NaN
# 3              NaN         NaT          NaT         1.000000               NaN
# 4              NaN         NaT          NaT         1.000000               NaN
# 5             99.0  2013-01-01    2953 days         0.916777         90.915127
# ...            ...         ...          ...              ...               ...
# 4663          99.0  2014-01-01     761 days         0.927387         96.916496
# 4664          99.0  2014-01-01     761 days         0.927387         96.916496
# 4665           NaN         NaT          NaT         1.000000               NaN
# 4666          99.0  1991-01-01    9162 days         0.875638         73.915811
# 4667          99.0  2014-01-01     761 days         0.927387         96.916496
#
# [92622 rows x 20 columns]

# %%
df['Postal District'].value_counts()
df['PD_processed'] = df['Postal District'].apply(lambda x: 'other' if x in [6, 25, 26] else x)
df = pd.get_dummies(df, columns = ['PD_processed'], prefix = 'District')
df.drop('District_3', axis=1, inplace=True)

# %%
df = pd.get_dummies(df, columns=['Type of Sale'], prefix = 'SaleType', drop_first=True)

# %%
df['Floor_low'] = df['Floor Level'].str.extract(r'([B0-9]+) to')
df['Floor_high'] = df["Floor Level"].str.extract(r'to ([B0-9]+)')
#process any B1-B5 floor levels to an int
df['low_processed'] = df['Floor_low'].apply(lambda x: -1 if x == 'B1' else x)
df['high_processed'] = df['Floor_high'].apply(lambda x: -5 if x == "B5" else x)
df['Floor_number'] = df['high_processed'].astype(float) + df['low_processed'].astype(float) / 2.0
#df[floor_number]

df['dt_sale'] = pd.to_datetime(df['Date of Sale'], format='%b-%y')
df['Period'] = pd.PeriodIndex(df['dt_sale'], freq='Q') #quarterly analysis
df = pd.get_dummies(df, columns= ['Period'])

# %%
df['log_price_psf'] = np.log(df['Unit Price ($psf)'])
df['log_area_sqft'] = np.log(df['Area (Sqft)'])

target_columns = ['log_price_psf', 'log_area_sqft', 'Type_Condominium', 'Building_age', 'Relative_tenure', 'Floor_number'] + [c for c in df.columns if c.startswith('District_') or c.startswith('SaleType_') or c.startswith('Period_')]

df2 = df[target_columns]
df2
# Out:
#       log_price_psf  log_area_sqft  Type_Condominium Building_age  \
# S/N
# 1          7.259820       7.366445             False    5875 days
# 2          7.162397       7.512071              True          NaT
# 3          7.207860       7.228388              True          NaT
# 4          6.839476       7.563720              True          NaT
# 5          7.483244       6.535241              True    2953 days
# ...             ...            ...               ...          ...
# 4663       6.894670       6.680855              True     761 days
# 4664       6.968850       6.818924              True     761 days
# 4665       7.198184       6.345636             False          NaT
# 4666       6.586172       6.887553              True    9162 days
# 4667       6.862758       6.887553             False     761 days
#
#       Relative_tenure  Floor_number  District_1  District_1  District_1  \
# S/N
# 1            0.899753          35.5        True        True        True
# 2            1.000000           5.5       False       False       False
# 3            1.000000           5.5       False       False       False
# 4            1.000000           5.5       False       False       False
# 5            0.916777          13.0       False       False       False
# ...               ...           ...         ...         ...         ...
# 4663         0.927387           5.5       False       False       False
# 4664         0.927387          20.5       False       False       False
# 4665         1.000000           5.5       False       False       False
# 4666         0.875638           5.5       False       False       False
# 4667         0.927387          13.0       False       False       False
#
#       District_2  ...  Period_2020Q1  Period_2020Q1  Period_2020Q2  \
# S/N               ...
# 1          False  ...          False          False          False
# 2          False  ...          False          False          False
# 3          False  ...          False          False          False
# 4          False  ...          False          False          False
# 5          False  ...          False          False          False
# ...          ...  ...            ...            ...            ...
# 4663       False  ...          False          False          False
# 4664       False  ...          False          False          False
# 4665       False  ...          False          False          False
# 4666       False  ...          False          False          False
# 4667       False  ...          False          False          False
#
#       Period_2020Q2  Period_2020Q3  Period_2020Q3  Period_2020Q4  \
# S/N
# 1             False          False          False          False
# 2             False          False          False          False
# 3             False          False          False          False
# 4             False          False          False          False
# 5             False          False          False          False
# ...             ...            ...            ...            ...
# 4663          False          False          False          False
# 4664          False          False          False          False
# 4665          False          False          False          False
# 4666          False          False          False          False
# 4667          False          False          False          False
#
#       Period_2020Q4  Period_2021Q1  Period_2021Q1
# S/N
# 1             False           True           True
# 2             False           True           True
# 3             False           True           True
# 4             False           True           True
# 5             False           True           True
# ...             ...            ...            ...
# 4663          False          False          False
# 4664          False          False          False
# 4665          False          False          False
# 4666          False          False          False
# 4667          False          False          False
#
# [92622 rows x 308 columns]

# %%
mean_building_age = df['Building_age'].mean()
mean_relative_tenure = df['Relative_tenure'].mean()
mean_Floor_number = df['Floor_number'].mean()
df2 = df2.fillna({'Building_age' : mean_building_age, 'Relative_tenure' : 
                mean_relative_tenure, 'Floor_number' : mean_Floor_number})
df2 #processed data frame, with no NAs, perhnaps
df2.isnull().sum()
df2.to_csv('ura_data_processed.csv')
print('Saved')
# Out:
# Saved
